# %%
from vizualization import plot_2d_heatmaps_interpolated, plot_2d_heatmaps_interpolated_Katya

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot_2d_heatmaps_interpolated('../results08_10_2025_CTRVIS/Results_synthetic_non-robust_mse_CTR_CVR.csv',
'../results08_10_2025_CTRVIS/Results_synthetic_robust_mse_CTR_CVR.csv',
'Results_synthetic_mse_CTR_CVR_2d_final.png')
# Out:
# <string>:43: UserWarning: The figure layout has changed to tight
# <string>:43: UserWarning: The figure layout has changed to tight
# <string>:43: UserWarning: The figure layout has changed to tight
# <string>:43: UserWarning: The figure layout has changed to tight

# %%
plot_2d_heatmaps_interpolated(
    '../results08_10_2025_CTRVIS/Results_ipinyou_non-robust_mse_CTR_CVR.csv',
    '../results08_10_2025_CTRVIS/Results_ipinyou_robust_mse_CTR_CVR.csv',
    'Results_ipinyou_mse_CTR_CVR_2d_final.png')
# Out:
# <string>:43: UserWarning: The figure layout has changed to tight
# <string>:43: UserWarning: The figure layout has changed to tight
# <string>:43: UserWarning: The figure layout has changed to tight
# <string>:43: UserWarning: The figure layout has changed to tight

# %%
plot_2d_heatmaps_interpolated_Katya(
                                    '../results08_10_2025_CTRVIS/metrics_mse_BAT_CTR_CVR.csv',
                                    '_results_mse_BAT_CTR_CVR_2d_final.png'
                                    )
# Out:
# /Users/easolodneva/Documents/GitHub/robust-autobidding-noisy-conversions/plots/vizualization.py:633: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /Users/easolodneva/Documents/GitHub/robust-autobidding-noisy-conversions/plots/vizualization.py:633: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /Users/easolodneva/Documents/GitHub/robust-autobidding-noisy-conversions/plots/vizualization.py:633: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /Users/easolodneva/Documents/GitHub/robust-autobidding-noisy-conversions/plots/vizualization.py:633: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
